# %% [markdown]
# ## AMI corpus.
# Go through the list of files and extract passage and the summaries, using the DialogueActs as intermediary

# %%
import glob, os
#import xml.etree.ElementTree as et
from lxml import etree as et
from collections import OrderedDict, defaultdict
ROOT_DIR = "/Users/haileywu/Desktop/W266-fall-2020-hwu-rnair/data/AMI_manual/ami_public"

# %% [markdown]
# ### Extract words

# %%
meeting_dict = dict() # key = meeting, value = ordered dict of word id: word
cur_word = None
for word_f in sorted(glob.glob(ROOT_DIR+"/words/*xml")):
    m = word_f.split("/")[-1].split(".")
    meeting_name = m[0]+"."+m[1]
    root = et.parse(word_f).getroot()
    nodes = root.findall('*')
    meet_words = OrderedDict()

    for node in nodes:
        if node.tag=='w':
            meet_words[node.attrib['{http://nite.sourceforge.net/}id']] = node.text
            cur_word = node.text
        for w in node.values():
            if "disfmarker" in w:
                meet_words [node.attrib['{http://nite.sourceforge.net/}id']] = cur_word
    meeting_dict[meeting_name] = meet_words
    
#meeting_dict['Bdb001.D']['Bdb001.w.2,391']

# %% [markdown]
# ##### Extract complete text and store in files under ../ICSI_plus_NXT/processing/_meeting_id_words.txt file

# %%
len(meeting_dict.keys())

for meeting, words in meeting_dict.items():
    with open("../data/AMI_manual/processing/"+meeting+"_words.txt", "w") as f:
        for word in words.values():
            f.write(word)
            f.write(" ")

# %% [markdown]
# ### Extract dialogues

# %% [markdown]
# Dialogues are equivalent to complete sentences

# %%
meeting_dialogues = dict() # key = meeting name, value = list of tuples start, end word ids(end can be same as start)
for dialog_f in sorted(glob.glob(ROOT_DIR+"/dialogueActs/*act.xml")):
    m = dialog_f.split("/")[-1].split(".")
    meeting_name = m[0]+"."+m[1]
    root = et.parse(dialog_f).getroot()
    dlist = root.findall('dact')
    for dl in dlist:
        nodes = dl.findall("{http://nite.sourceforge.net/}child")
        dialog_id = dl.attrib['{http://nite.sourceforge.net/}id']
        dialog_id = dialog_id.split('.')
        del dialog_id[3]
        dialog_id = '.'.join(dialog_id)
        #print(dialog_id)
        for dl_c in nodes:
            words = dl_c.attrib['href']
            words = words.split("#")[1]
            try:
                start, end = words.split("..")
                start, end = start.replace("id", ""), end.replace("id", "")
                start, end = start.replace("(", ""), end.replace("(", "")
                start, end = start.replace(")", ""), end.replace(")", "")
    #            print(start, end)
            except:
                start = end = words.replace("id", "").replace("(", "").replace(")", "")
                
    #            print(start)
            if meeting_name not in meeting_dialogues:
                meeting_dialogues[meeting_name] = OrderedDict()
            meeting_dialogues[meeting_name][dialog_id] = ((start, end))

# %% [markdown]
# #####  Extract complete dialogues and store in files under ../AMI_manual/processing/_meeting_id_dialogues.txt file

# %%
print(len(meeting_dialogues.keys()))
dialogues = dict() # key = dialogue id, value = text (required for summaries)
for meeting, sentence_map in meeting_dialogues.items():
    with open("../data/AMI_manual/processing/"+meeting+"_dialogues.txt", "w") as f:
        starts, ends = dict(), dict()
        for d_id, (start, end) in sentence_map.items():
            starts[start] = d_id
            ends[end] = d_id
        #go through entire text and start printing if start token is in "starts". stop printing if end token is in "ends"
        print_w = False
        cur_d = None
        for word_id, word in meeting_dict[meeting].items():
            if word_id in starts:
                cur_d = starts[word_id]
                print_w = True
            if print_w:
                f.write(word + " ")
                dialogues[cur_d] = dialogues.get(cur_d, "") + word+ " "
            if word_id in ends:
                print_w = False
                f.write("\n")
# Out:
# 556

# %% [markdown]
# ### Extract summaries

# %%
meeting_summaries = defaultdict(list) # key = meeting name, value = list of tuples start, end word ids(end can be same as start)

for dialog_f in sorted(glob.glob(ROOT_DIR+"/extractive/*extsumm.xml")):
    m = dialog_f.split("/")[-1].split(".")
    meeting_name = m[0]+"."+m[1]
    root = et.parse(dialog_f).getroot()
    dlist = root.findall('extsumm/{http://nite.sourceforge.net/}child')
    for dl in dlist:
        words = dl.attrib['href']
        words = words.split("#")[1]
        try:
            start, end = words.split("..")
            start, end = start.replace("id", ""), end.replace("id", "")
            start, end = start.replace("(", ""), end.replace("(", "")
            start, end = start.replace(")", ""), end.replace(")", "")
            start, end = start.split('.'),end.split('.')
            del start[3],end[3]
            start, end = '.'.join(start),'.'.join(end)
#            print(start, end)
        except:
            start = end = words.replace("id", "").replace("(", "").replace(")", "")
            start, end = start.split('.'),end.split('.')
            del start[3],end[3]
            start, end = '.'.join(start),'.'.join(end)
            #            print(start)
        meeting_summaries[meeting_name].append((start, end))

# %%
for meeting, summ_list in meeting_summaries.items():
    with open("../data/AMI_manual/processing/"+meeting+"_summaries.txt", "w") as f:
        for start, end in summ_list:
            st = int(start.split('.')[3])
            en = int(start.split('.')[3])+1
            for d in range(st, en):
                key = start.split(str(st))[0]+str(d)
                if key not in dialogues:
                    print("missing", key)
                else:
                    f.write(dialogues.get(key))
                    f.write("\n")
# Out:
# missing ES2002a.B.dialog-act.3
# missing ES2002a.B.dialog-act.33
# missing ES2002b.B.dialog-act.24
# missing ES2002b.C.dialog-act.4
# missing ES2002b.C.dialog-act.19
# missing ES2002b.C.dialog-act.39
# missing ES2002b.C.dialog-act.43
# missing ES2002b.B.dialog-act.140
# missing ES2002b.A.dialog-act.116
# missing ES2
# missing ES2002c.C.dialog-act.29
# missing ES2002c.B.dialog-act.71
# missing ES2002c.C.dialog-act.42
# missing ES2002c.C.dialog-act.48
# missing ES2
# missing ES2003a.C.dialog-act.17
# missing ES2003
# missing ES2003b.C.dialog-act.42
# missing ES2003b.C.dialog-act.90
# missing ES2003b.C.dialog-act.134
# missing ES2003b.A.dialog-act.18
# missing ES20
# missing ES2003b.A.dialog-act.60
# missing ES2003b.B.dialog-act.129
# missing ES2003b.A.dialog-act.104
# missing ES200
# missing ES2003b.A.dialog-act.120
# missing ES2003c.C.dialog-act.54
# missing ES2003c.C.dialog-act.71
# missing ES2003c.C.dialog-act.95
# missing ES2003c.A.dialog-act.102
# missing ES2003c.C.dialog-act.148
# missing ES200
# missing ES2003c.D.dialog-act.126
# missing ES20
# missing ES2003
# missing ES20
# missing ES2
# missing ES2003d.A.dialog-act.150
# missing ES2003d.C.dialog-act.346
# missing ES2004a.C.dialog-act.10
# missing ES20
# missing ES2004b.D.dialog-act.52
# missing ES2004b.D.dialog-act.64
# missing ES2004b.A.dialog-act.101
# missing ES20
# missing ES2004c.D.dialog-act.104
# missing ES20
# missing ES2004d.C.dialog-act.123
# missing ES2013d.C.dialog-act.115
# missing ES2013d.C.dialog-act.127
# missing ES2013d.D.dialog-act.93
# missing ES2014
# missing ES201
# missing ES2
# missing ES2014
# missing ES20
# missing ES2014a.A.dialog-act.38
# missing ES2014a.C.dialog-act.36
# missing ES2014a.C.dialog-act.45
# missing ES2014b.B.dialog-act.61
# missing ES2014b.B.dialog-act.80
# missing ES2014b.C.dialog-act.24
# missing ES2014b.A.dialog-act.52
# missing ES2014b.B.dialog-act.144
# missing ES2014b.B.dialog-act.213
# missing ES2014b.A.dialog-act.244
# missing ES201
# missing ES2014
# missing ES2014c.B.dialog-act.92
# missing ES2014c.B.dialog-act.228
# missing ES2014c.A.dialog-act.275
# missing ES201
# missing ES2014
# missing ES201
# missing ES2014
# missing ES2014
# missing ES2014d.A.dialog-act.107
# missing ES2014d.D.dialog-act.84
# missing ES2014d.D.dialog-act.162
# missing ES2014d.A.dialog-act.192
# missing ES2014d.C.dialog-act.91
# missing ES2014d.B.dialog-act.132
# missing ES2014d.D.dialog-act.222
# missing ES2014d.D.dialog-act.228
# missing ES2014d.A.dialog-act.278
# missing ES2014d.B.dialog-act.217
# missing ES2014d.A.dialog-act.347
# missing ES2014d.D.dialog-act.369
# missing ES2014d.A.dialog-act.394
# missing ES2014d.D.dialog-act.356
# missing ES2014d.B.dialog-act.237
# missing ES2014d.C.dialog-act.154
# missing ES2014d.C.dialog-act.157
# missing ES2014d.D.dialog-act.198
# missing ES2015
# missing ES2015a.C.dialog-act.4
# missing ES2015a.C.dialog-act.57
# missing ES2015
# missing ES2015b.D.dialog-act.13
# missing ES20
# missing ES201
# missing ES2015c.B.dialog-act.36
# missing ES2015c.B.dialog-act.99
# missing ES2015c.D.dialog-act.111
# missing ES2015d.B.dialog-act.140
# missing ES2015d.D.dialog-act.266
# missing ES2015d.A.dialog-act.212
# missing ES2015d.D.dialog-act.309
# missing ES2016a.D.dialog-act.3
# missing ES2016
# missing ES201
# missing ES2
# missing ES20
# missing ES2016
# missing ES2016b.A.dialog-act.30
# missing ES20
# missing ES2016b.B.dialog-act.65
# missing ES2016b.A.dialog-act.225
# missing ES2016b.C.dialog-act.142
# missing ES2016c.A.dialog-act.9
# missing ES2016
# missing ES2016
# missing ES20
# missing ES20
# missing ES2016c.B.dialog-act.30
# missing ES2016c.B.dialog-act.55
# missing ES2016c.B.dialog-act.157
# missing ES2016c.A.dialog-act.129
# missing ES2016c.A.dialog-act.145
# missing ES2016
# missing ES2016
# missing ES20
# missing ES2016
# missing ES20
# missing ES2016d.D.dialog-act.38
# missing ES2016d.A.dialog-act.96
# missing ES2016d.B.dialog-act.102
# missing IS10
# missing IS1000a.A.dialog-act.50
# missing IS1000a.B.dialog-act.168
# missing IS1000a.C.dialog-act.90
# missing IS100
# missing IS1000b.D.dialog-act.112
# missing IS1000b.B.dialog-act.98
# missing IS1000b.C.dialog-act.49
# missing IS1000b.B.dialog-act.174
# missing IS1000c.A.dialog-act.26
# missing IS1000c.A.dialog-act.88
# missing IS1000c.D.dialog-act.67
# missing IS100
# missing IS1000c.B.dialog-act.162
# missing IS10
# missing IS1000d.D.dialog-act.88
# missing IS100
# missing IS1000d.A.dialog-act.75
# missing IS100
# missing IS1000d.B.dialog-act.205
# missing IS1000d.C.dialog-act.195
# missing IS1000d.B.dialog-act.314
# missing IS1000d.A.dialog-act.386
# missing IS1000d.B.dialog-act.399
# missing IS1000d.C.dialog-act.330
# missing IS1001a.A.dialog-act.57
# missing IS1001a.A.dialog-act.91
# missing IS1001a.A.dialog-act.121
# missing IS10
# missing IS10
# missing IS1001b.B.dialog-act.36
# missing IS1001b.B.dialog-act.51
# missing IS1001b.D.dialog-act.2
# missing IS1001b.A.dialog-act.64
# missing IS1001b.D.dialog-act.42
# missing IS1001b.D.dialog-act.82
# missing IS1001b.C.dialog-act.111
# missing IS1001c.A.dialog-act.126
# missing IS1001d.A.dialog-act.20
# missing IS1001d.A.dialog-act.58
# missing IS1001d.D.dialog-act.42
# missing IS10
# missing IS100
# missing IS1001d.D.dialog-act.86
# missing IS1001d.B.dialog-act.23
# missing IS1001d.C.dialog-act.42
# missing IS1001d.D.dialog-act.103
# missing IS1001d.C.dialog-act.74
# missing IS1002
# missing IS1002
# missing IS1002b.B.dialog-act.112
# missing IS1002b.B.dialog-act.127
# missing IS1002b.B.dialog-act.178
# missing IS100
# missing IS1002c.B.dialog-act.131
# missing IS1002c.B.dialog-act.135
# missing IS1002c.B.dialog-act.170
# missing IS1002c.D.dialog-act.158
# missing IS10
# missing IS1003
# missing IS1003a.C.dialog-act.44
# missing IS1003
# missing IS1003c.A.dialog-act.18
# missing IS100
# missing IS1003c.A.dialog-act.187
# missing IS1003c.B.dialog-act.217
# missing IS1003d.A.dialog-act.14
# missing IS1003d.C.dialog-act.20
# missing IS1003d.A.dialog-act.70
# missing IS1003d.D.dialog-act.58
# missing IS1003d.D.dialog-act.62
# missing IS1003d.B.dialog-act.149
# missing IS1003d.B.dialog-act.166
# missing IS1003d.D.dialog-act.133
# missing IS1003d.A.dialog-act.236
# missing IS1003d.B.dialog-act.250
# missing IS1003d.B.dialog-act.324
# missing IS1004
# missing IS1
# missing IS1004a.B.dialog-act.11
# missing IS1004
# missing IS1004b.A.dialog-act.8
# missing IS1004
# missing IS1004b.A.dialog-act.40
# missing IS1004b.B.dialog-act.52
# missing IS1004b.B.dialog-act.179
# missing IS1004b.B.dialog-act.190
# missing IS1004c.D.dialog-act.49
# missing IS1004c.A.dialog-act.79
# missing IS1004c.B.dialog-act.120
# missing IS100
# missing IS1004c.B.dialog-act.228
# missing IS1004c.A.dialog-act.213
# missing IS1004
# missing IS1004d.A.dialog-act.20
# missing IS1004d.B.dialog-act.34
# missing IS100
# missing IS1004d.A.dialog-act.125
# missing IS1004d.B.dialog-act.131
# missing IS1004d.B.dialog-act.142
# missing IS1004d.C.dialog-act.153
# missing IS1004d.A.dialog-act.248
# missing IS1004d.D.dialog-act.141
# missing IS1004d.B.dialog-act.219
# missing IS1004d.A.dialog-act.306
# missing IS1004d.B.dialog-act.233
# missing IS1004d.A.dialog-act.341
# missing IS1005a.A.dialog-act.78
# missing IS10
# missing IS10
# missing IS1005b.A.dialog-act.165
# missing IS1005b.B.dialog-act.170
# missing IS1005c.D.dialog-act.21
# missing IS1006a.A.dialog-act.2
# missing IS1006a.B.dialog-act.23
# missing IS1006a.A.dialog-act.60
# missing IS1006a.D.dialog-act.51
# missing IS1006a.D.dialog-act.70
# missing IS1006a.D.dialog-act.89
# missing IS1006a.A.dialog-act.135
# missing IS10
# missing IS100
# missing IS100
# missing IS1006b.A.dialog-act.76
# missing IS1006b.B.dialog-act.137
# missing IS1006b.D.dialog-act.235
# missing IS1006b.C.dialog-act.92
# missing IS1006b.D.dialog-act.263
# missing IS1006c.C.dialog-act.42
# missing IS1006c.A.dialog-act.24
# missing IS1006c.C.dialog-act.64
# missing IS1006c.D.dialog-act.52
# missing IS1006c.D.dialog-act.61
# missing IS1006c.B.dialog-act.75
# missing IS1006c.C.dialog-act.126
# missing IS1006c.D.dialog-act.94
# missing IS1006c.D.dialog-act.148
# missing IS1006c.D.dialog-act.211
# missing IS1006c.D.dialog-act.262
# missing IS1006c.A.dialog-act.178
# missing IS1006d.D.dialog-act.27
# missing IS1006d.C.dialog-act.38
# missing IS1006d.A.dialog-act.128
# missing IS1006d.A.dialog-act.237
# missing IS1006d.D.dialog-act.325
# missing IS1006d.C.dialog-act.288
# missing IS1006d.A.dialog-act.129
# missing IS1006d.D.dialog-act.181
# missing IS1007
# missing IS1007a.C.dialog-act.33
# missing IS1007
# missing IS10
# missing IS1007
# missing IS1007b.B.dialog-act.94
# missing IS1007b.C.dialog-act.84
# missing IS1007b.D.dialog-act.49
# missing IS1007b.B.dialog-act.135
# missing IS1007b.D.dialog-act.60
# missing IS1007b.B.dialog-act.150
# missing IS1
# missing IS1007
# missing IS1007c.A.dialog-act.21
# missing IS10
# missing IS1007c.B.dialog-act.159
# missing IS1007c.D.dialog-act.57
# missing IS1007c.D.dialog-act.62
# missing IS100
# missing IS1007c.B.dialog-act.280
# missing IS1
# missing IS1007
# missing IS10
# missing IS10
# missing IS1007
# missing IS1007d.B.dialog-act.46
# missing IS1007d.B.dialog-act.193
# missing IS100
# missing IS1007d.B.dialog-act.269
# missing IS1007d.A.dialog-act.88
# missing IS1007d.B.dialog-act.274
# missing IS1007d.B.dialog-act.287
# missing IS1007d.B.dialog-act.317
# missing IS1007d.C.dialog-act.208
# missing IS1
# missing IS1008
# missing IS1008a.D.dialog-act.11
# missing IS1008a.C.dialog-act.30
# missing IS100
# missing IS1008b.B.dialog-act.123
# missing IS1008c.C.dialog-act.39
# missing IS1008c.D.dialog-act.66
# missing IS100
# missing IS10
# missing IS1008d.C.dialog-act.76
# missing IS1008d.B.dialog-act.32
# missing IS1008d.D.dialog-act.70
# missing IS1008d.C.dialog-act.123
# missing IS1008d.C.dialog-act.139
# missing IS1008d.B.dialog-act.105
# missing IS1009a.A.dialog-act.31
# missing IS1009a.D.dialog-act.41
# missing IS1009b.A.dialog-act.14
# missing IS100
# missing IS1009b.D.dialog-act.130
# missing IS1009b.A.dialog-act.125
# missing IS1009c.A.dialog-act.20
# missing IS100
# missing IS10
# missing IS1009
# missing IS1009d.A.dialog-act.88
# missing IS1009d.D.dialog-act.260
# missing TS3
# missing TS3003a.A.dialog-act.66
# missing TS3003a.A.dialog-act.162
# missing TS30
# missing TS3003b.A.dialog-act.114
# missing TS3003b.A.dialog-act.228
# missing TS3003b.A.dialog-act.263
# missing TS3003b.A.dialog-act.284
# missing TS3003c.B.dialog-act.5
# missing TS3003c.B.dialog-act.21
# missing TS3
# missing TS30
# missing TS3003c.D.dialog-act.90
# missing TS30
# missing TS30
# missing TS3003d.A.dialog-act.79
# missing TS30
# missing TS3003d.A.dialog-act.180
# missing TS3003d.C.dialog-act.113
# missing TS3003d.C.dialog-act.134
# missing TS3003d.A.dialog-act.467
# missing TS30
# missing TS3004a.D.dialog-act.88
# missing TS3004a.B.dialog-act.74
# missing TS3004a.C.dialog-act.59
# missing TS3004
# missing TS30
# missing TS3004b.D.dialog-act.109
# missing TS3004b.C.dialog-act.98
# missing TS300
# missing TS3004b.B.dialog-act.264
# missing TS30
# missing TS30
# missing TS3004c.A.dialog-act.53
# missing TS30
# missing TS3004c.A.dialog-act.70
# missing TS3004c.B.dialog-act.138
# missing TS300
# missing TS3004c.B.dialog-act.365
# missing TS3004
# missing TS3004d.B.dialog-act.9
# missing TS3004d.C.dialog-act.23
# missing TS3004d.D.dialog-act.140
# missing TS3004d.D.dialog-act.163
# missing TS3004d.A.dialog-act.251
# missing TS3004d.C.dialog-act.196
# missing TS300
# missing TS3005a.D.dialog-act.27
# missing TS30
# missing TS3005b.D.dialog-act.23
# missing TS3005b.D.dialog-act.45
# missing TS3005b.A.dialog-act.47
# missing TS3005b.D.dialog-act.197
# missing TS3005b.B.dialog-act.212
# missing TS3005b.D.dialog-act.289
# missing TS3005
# missing TS3005c.B.dialog-act.168
# missing TS300
# missing TS3005c.C.dialog-act.344
# missing TS3005
# missing TS30
# missing TS3005d.C.dialog-act.42
# missing TS3005d.B.dialog-act.68
# missing TS3005d.B.dialog-act.78
# missing TS3005d.D.dialog-act.146
# missing TS3005d.B.dialog-act.451
# missing TS300
# missing TS3005d.B.dialog-act.644
# missing TS3005d.A.dialog-act.444
# missing TS3006a.B.dialog-act.21
# missing TS3006a.C.dialog-act.41
# missing TS3006a.C.dialog-act.49
# missing TS3006a.A.dialog-act.151
# missing TS3006a.B.dialog-act.69
# missing TS3006a.A.dialog-act.248
# missing TS3006b.A.dialog-act.18
# missing TS3006b.A.dialog-act.66
# missing TS3006c.C.dialog-act.11
# missing TS30
# missing TS3006c.D.dialog-act.71
# missing TS3006c.C.dialog-act.234
# missing TS3006c.D.dialog-act.220
# missing TS3006c.C.dialog-act.269
# missing TS3006c.A.dialog-act.280
# missing TS3006d.C.dialog-act.16
# missing TS3006d.D.dialog-act.122
# missing TS3006d.C.dialog-act.117
# missing TS3006d.D.dialog-act.253
# missing TS3006d.D.dialog-act.318
# missing TS3006d.D.dialog-act.341
# missing TS3006d.C.dialog-act.188
# missing TS3006d.C.dialog-act.284
# missing TS3006d.A.dialog-act.427
# missing TS3
# missing TS3007a.A.dialog-act.23
# missing TS30
# missing TS3007a.A.dialog-act.74
# missing TS3007a.A.dialog-act.91
# missing TS3007b.A.dialog-act.18
# missing TS3007b.A.dialog-act.24
